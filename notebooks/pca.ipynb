# %%
import pandas as pd
from cairn import pca
from cairn.io import load_biallelic_snp_calls
from yaspin import yaspin

# %%
# Define zarr base path and metadata
zarr_p = "/Users/dennistpw/Projects/AsGARD/data/variants_combined_cohorts/combined_cohorts.{contig}.zarr"
metadata_p =  "/Users/dennistpw/Projects/AsGARD/metadata/cease_combinedmetadata.20250715.tsv"
metadata = pd.read_csv(metadata_p, sep='\t')
# Out:
#      callset_order  sample_id  conc (ng/ul) sequencing_date  \
# 0                0        A01          5.02      01/07/2025
# 1                1        A02          4.28      01/07/2025
# 2                2        A03          3.60      01/07/2025
# 3                3        A04          6.92      01/07/2025
# 4                4        A05         18.00      01/07/2025
# ..             ...        ...           ...             ...
# 596            596  Yeme_A_13         12.53      28/04/2024
# 597            597  Yeme_A_14         20.47      28/04/2024
# 598            598  Yeme_A_15         14.93      28/04/2024
# 599            599  Yeme_A_17         19.29      28/04/2024
# 600            600  Yeme_A_19          4.87      28/04/2024
#
#               sampleset_id                                       fastq_1_path  \
# 0                      NaN                                                NaN
# 1                      NaN                                                NaN
# 2                      NaN                                                NaN
# 3                      NaN                                                NaN
# 4                      NaN                                                NaN
# ..                     ...                                                ...
# 596  eth.djib.yem.20240606  /home/dennist/lstm_data/cease/reads_gvcf/eth.y...
# 597  eth.djib.yem.20240606  /home/dennist/lstm_data/cease/reads_gvcf/eth.y...
# 598  eth.djib.yem.20240606  /home/dennist/lstm_data/cease/reads_gvcf/eth.y...
# 599  eth.djib.yem.20240606  /home/dennist/lstm_data/cease/reads_gvcf/eth.y...
# 600  eth.djib.yem.20240606  /home/dennist/lstm_data/cease/reads_gvcf/eth.y...
#
#                                           fastq_2_path  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 596  /home/dennist/lstm_data/cease/reads_gvcf/eth.y...
# 597  /home/dennist/lstm_data/cease/reads_gvcf/eth.y...
# 598  /home/dennist/lstm_data/cease/reads_gvcf/eth.y...
# 599  /home/dennist/lstm_data/cease/reads_gvcf/eth.y...
# 600  /home/dennist/lstm_data/cease/reads_gvcf/eth.y...
#
#                                               bam_path  \
# 0    /home/dennist/lstm_data/cease/reads_gvcf/eth.k...
# 1    /home/dennist/lstm_data/cease/reads_gvcf/eth.k...
# 2    /home/dennist/lstm_data/cease/reads_gvcf/eth.k...
# 3    /home/dennist/lstm_data/cease/reads_gvcf/eth.k...
# 4    /home/dennist/lstm_data/cease/reads_gvcf/eth.k...
# ..                                                 ...
# 596  /home/dennist/lstm_data/cease/reads_gvcf/eth.y...
# 597  /home/dennist/lstm_data/cease/reads_gvcf/eth.y...
# 598  /home/dennist/lstm_data/cease/reads_gvcf/eth.y...
# 599  /home/dennist/lstm_data/cease/reads_gvcf/eth.y...
# 600  /home/dennist/lstm_data/cease/reads_gvcf/eth.y...
#
#                                               vcf_path  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 596  /home/dennist/lstm_data/cease/reads_gvcf/eth.y...
# 597  /home/dennist/lstm_data/cease/reads_gvcf/eth.y...
# 598  /home/dennist/lstm_data/cease/reads_gvcf/eth.y...
# 599  /home/dennist/lstm_data/cease/reads_gvcf/eth.y...
# 600  /home/dennist/lstm_data/cease/reads_gvcf/eth.y...
#
#                                    legacy_id  ...  longitude  \
# 0                                        NaN  ...  40.158987
# 1                                        NaN  ...  40.158987
# 2                                        NaN  ...  40.158987
# 3                                        NaN  ...  40.158987
# 4                                        NaN  ...  40.158987
# ..                                       ...  ...        ...
# 596  Yeme_A_12_EKDN240018904-1A_22JVYWLT3_L7  ...  45.020000
# 597  Yeme_A_13_EKDN240018905-1A_223WLHLT4_L2  ...  45.020000
# 598  Yeme_A_14_EKDN240018906-1A_22JVYWLT3_L7  ...  45.020000
# 599  Yeme_A_15_EKDN240018907-1A_22772HLT4_L8  ...  45.020000
# 600  Yeme_A_17_EKDN240018909-1A_22JVYWLT3_L7  ...  45.020000
#
#     sequencing_qc_pass data_qc_pass  analysis_pop  pop_code  \
# 0                  NaN          NaN           NaN       ETN
# 1                  NaN          NaN           NaN       ETN
# 2                  NaN          NaN           NaN       ETN
# 3                  NaN          NaN           NaN       ETN
# 4                  NaN          NaN           NaN       ETN
# ..                 ...          ...           ...       ...
# 596                1.0          1.0         Yemen       YEM
# 597                1.0          1.0         Yemen       YEM
# 598                1.0          1.0         Yemen       YEM
# 599                1.0          1.0         Yemen       YEM
# 600                1.0          1.0         Yemen       YEM
#
#             SuperPopulation  collection_method collection_date  \
# 0    Horn of Africa & Yemen          Prokopack      01/11/2024
# 1    Horn of Africa & Yemen          Prokopack      01/11/2024
# 2    Horn of Africa & Yemen          Prokopack      01/11/2024
# 3    Horn of Africa & Yemen          Prokopack      01/11/2024
# 4    Horn of Africa & Yemen          Prokopack      01/11/2024
# ..                      ...                ...             ...
# 596  Horn of Africa & Yemen                CDC      01/07/2022
# 597  Horn of Africa & Yemen                CDC      01/07/2022
# 598  Horn of Africa & Yemen                CDC      01/07/2022
# 599  Horn of Africa & Yemen                CDC      01/07/2022
# 600  Horn of Africa & Yemen                CDC      01/07/2022
#
#                               note Unnamed: 23
# 0                              NaN         NaN
# 1                              NaN         NaN
# 2                              NaN         NaN
# 3                              NaN         NaN
# 4                              NaN         NaN
# ..                             ...         ...
# 596  collected btw 07/2022-02/2023         NaN
# 597  collected btw 07/2022-02/2023         NaN
# 598  collected btw 07/2022-02/2023         NaN
# 599  collected btw 07/2022-02/2023         NaN
# 600  collected btw 07/2022-02/2023         NaN
#
# [601 rows x 24 columns]

# %%
p = pca.run_pca(
    zarr_base_path = zarr_p,
    region = "CM023248:1000000-20000000",
    df_samples = metadata,
    n_snps=50_000,
    genotype_var ='call_genotype',
    pos_var = "variant_position",
    cache_path = './results_cache/',
    sample_query = 'country == "Ethiopia"'
    )
# Out:
# running analysis: cce542dac2f0dee394660f9fdc87992d
# ⠦ Loading genotypes...
